# %%
from romgw.config.constants import PROJECT_ROOT
from romgw.plotting.core import plot_same_mode, plot_same_params
# from romgw.typing.core import MODE_VALUES
from romgw.config.constants import MODE_VALUES
from romgw.waveform.base import FullWaveform
from romgw.waveform.dataset import FullWaveformDataset
# Out:
# /home/connor/projects/reduced-order-modelling-of-gravitational-waves/src/romgw/maths/core.py:2: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %%
import romgw.plotting.custom_config

# %%
bbh_spin = "NS"
dataset = "test"
wf_dir = lambda mode: (
    PROJECT_ROOT / "data" / bbh_spin / dataset / mode / "full" / "raw"
)

# %%
seed = 0

modes = {}
for mode in MODE_VALUES:
    modes[mode] = FullWaveform.from_directory(wf_dir(mode), seed)
plot_same_params(modes)

# %%
mode = "2,2"
n = 16
seed = 0
waveforms = FullWaveformDataset.from_directory(wf_dir(mode), n, seed)
plot_same_mode(waveforms, verbose=False)
# Out:
# Waveforms loaded.
